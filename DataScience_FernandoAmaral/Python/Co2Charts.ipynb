# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")

# %%
base = pd.read_csv("../data/co2.csv")

base.head(10)
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3
# 5   Qn1  Quebec  nonchilled   675    39.2
# 6   Qn1  Quebec  nonchilled  1000    39.7
# 7   Qn2  Quebec  nonchilled    95    13.6
# 8   Qn2  Quebec  nonchilled   175    27.3
# 9   Qn2  Quebec  nonchilled   250    37.1

# %%
base.info
# Out:
# <bound method DataFrame.info of    Plant         Type   Treatment  conc  uptake
# 0    Qn1       Quebec  nonchilled    95    16.0
# 1    Qn1       Quebec  nonchilled   175    30.4
# 2    Qn1       Quebec  nonchilled   250    34.8
# 3    Qn1       Quebec  nonchilled   350    37.2
# 4    Qn1       Quebec  nonchilled   500    35.3
# ..   ...          ...         ...   ...     ...
# 79   Mc3  Mississippi     chilled   250    17.9
# 80   Mc3  Mississippi     chilled   350    17.9
# 81   Mc3  Mississippi     chilled   500    17.9
# 82   Mc3  Mississippi     chilled   675    18.9
# 83   Mc3  Mississippi     chilled  1000    19.9
#
# [84 rows x 5 columns]>

# %%
x = base.conc
y = base.uptake

# %%
uniques = list(set(base.Treatment))

uniques
# Out:
# ['chilled', 'nonchilled']

# %%
for i in range(len(uniques)):
    indice = base.Treatment == uniques[i]
    plt.scatter(x[indice], y[indice], label=uniques[i])
plt.legend(loc="lower right")

# %%
sns.scatterplot(data=base, x='conc', y='uptake', hue='Type')
plt.show()

# %%
q = base.loc[base['Type'] == 'Quebec']
m = base.loc[base['Type'] == 'Mississippi']

# %%
plt.figure(figsize=(10, 5))  # Ajuste o tamanho se necessário
plt.subplot(1, 2, 1)
sns.scatterplot(x=q.conc, y=q.uptake)
plt.title('Quebec')
# sns.scatterplot(data=base, x='conc', y='uptake', hue='Type')
plt.subplot(1, 2, 2)
sns.scatterplot(x=m.conc, y=m.uptake)
plt.title('Mississippi')
plt.tight_layout()
plt.show()

# %%
ch = base.loc[base['Treatment'] == 'chilled']
nc = base.loc[base['Treatment'] == 'nonchilled']

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(x=ch.conc, y=ch.uptake)
plt.title('Chilled')
plt.subplot(1, 2, 2)
sns.scatterplot(x=nc.conc, y=nc.uptake)
plt.title('Non chilled')
plt.tight_layout()
plt.show()
